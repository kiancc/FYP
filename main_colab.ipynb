# %% [markdown]
# <a href="https://colab.research.google.com/github/kiancc/FYP/blob/master/colanb_2.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import os
import sys
from google.colab import drive, userdata

# Retrieve your secret
token = userdata.get('github_fyp_token')
username = "kiancc"
repo_name = "FYP"

drive.mount('/content/drive')
# !pip install --upgrade git+https://github.com/ace-step/ACE-Step.git
os.environ['ACE_PIPELINE_DTYPE'] = 'float16'

# !git clone https://{token}@github.com/kiancc/FYP.git
# %cd FYP
sys.path.append(os.getcwd())

# !pip install -r requirements.txt

if "google.colab" in sys.modules:
    from google.colab import auth

    auth.authenticate_user()

# %%
# !pip install essentia

cloud_audio = "/content/drive/MyDrive/fyp_audio"
# cloud_prompts = "/content/master_prompts.csv" # this potentially redundant

prompts = 'data/prompts/master_prompts.csv'
test_prompts = 'data/prompts/test_prompts_small.csv'

from main import run_feature_extraction, run_generation

run_generation(cloud_audio, prompts)
run_feature_extraction(cloud_audio)
